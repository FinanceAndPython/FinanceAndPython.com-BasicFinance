# %%
payments = [100,200,300,400]
years = [5,10,15,20]
rates = [.01,.02,.03,.04]

# %%
for index in range(0,len(payments)):
    print(payments[index])
    print(years[index])
    print(rates[index])
    print("")
# Out:
# 100
# 5
# 0.01
#
# 200
# 10
# 0.02
#
# 300
# 15
# 0.03
#
# 400
# 20
# 0.04

# %%
def TVM(p,r,t,type):
    discount = (1+r)**t
    if type=="FV":
        A = p*discount
        return A
    if type=="PV":
        A = p/discount
        return A

# %%
for index in range(0,len(payments)):
    print(TVM(payments[index],years[index],rates[index],"PV"))
# Out:
# 98.22419709752423
# 190.63478193082776
# 276.0562951874625
# 354.1369311851404

# %%
total = 0
for index in range(0,len(payments)):
    total+= TVM(payments[index],years[index],rates[index],"PV")
print(total)
# Out:
# 919.0522054009549

# %%
def totalTVM(payments,years,rates):
    total = 0
    for index in range(0,len(payments)):
        total+= TVM(payments[index],years[index],rates[index],"PV")
    return total

# %%
totalTVM([100,200,300,400],[5,10,15,20],[.01,.02,.03,.04])
# Out:
# 919.0522054009549

# %%
payments = [100,200,300,400]
years = [5,10,15,20]
rates = [.01,.02,.03,.04]
totalTVM(payments,years,rates)
# Out:
# 919.0522054009549

# %%
payments = [-900,100,200,300,400]
years = [0,5,10,15,20]
rates = [.01,.01,.02,.03,.04]
totalTVM(payments,years,rates)
# Out:
# 19.052205400954904
